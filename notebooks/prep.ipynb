# %% [markdown]
# # Data Loading, Cleanup, and Normalization
#
# ## Objectives:
# 1. **Load raw JSON data** into a Pandas DataFrame.
# 2. **Ensure data integrity**:
#    - The `business_id` column should be unique and valid as a primary key.
#    - Handle any missing or duplicate values.
# 3. **Normalize data fields**:
#    - Ensure consistency in the `city` column.
#    - Split `categories` into separate rows.
#
# ## Assumptions:
# - The dataset contains `business_id`, `city`, and `categories` columns.
# - `categories` is a comma-separated string that needs to be expanded into multiple rows.
# - City names may have inconsistencies (e.g., different capitalizations, typos).
#
# ## Key Steps:
# 1. **Load raw_data.json**
# 2. **Clean business_id** (remove duplicates, handle nulls)
# 3. **Normalize city names** (formatting, spelling)
# 4. **Expand categories** (split multi-category rows into single entries)

# %%
import pandas as pd

file_path = "../data/raw/raw_data.json"
df = pd.read_json(file_path, lines=True)

df.head()
# Out:
#                            address  \
# 0           1616 Chapala St, Ste 2
# 1  87 Grasso Plaza Shopping Center
# 2             5255 E Broadway Blvd
# 3                      935 Race St
# 4                    101 Walnut St
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'Alcohol': 'u'none'', 'BikeParking': 'True', ...
# 4  {'BikeParking': 'True', 'BusinessAcceptsCredit...
#
#                                           categories           city  is_open  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...  Santa Barbara        0
# 1  Shipping Centers, Local Services, Notaries, Ma...         Affton        1
# 2  Department Stores, Shopping, Fashion, Home & G...         Tucson        0
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...   Philadelphia        1
# 4                          Brewpubs, Breweries, Food     Green Lane        1
#
#     latitude   longitude                      name postal_code  review_count  \
# 0  34.426679 -119.711197  Abby Rappoport, LAC, CMQ       93101             7
# 1  38.551126  -90.335695             The UPS Store       63123            15
# 2  32.223236 -110.880452                    Target       85711            22
# 3  39.955505  -75.155564        St Honore Pastries       19107            80
# 4  40.338183  -75.471659  Perkiomen Valley Brewery       18054            13
#
#    stars state             business_id  \
# 0    5.0    CA                     NaN
# 1    3.0    MO  mpf3x-BjTdTEA3yCZrAYPw
# 2    3.5    AZ  tUFrWirKiKi_TAnsVWINQQ
# 3    4.0    PA                     NaN
# 4    4.5    PA  mWMc6_wTdE0EUBKIGXDVfA
#
#                                                hours
# 0                                                NaN
# 1  {'Friday': '8:0-18:30', 'Monday': '0:0-0:0', '...
# 2  {'Friday': '8:0-23:0', 'Monday': '8:0-22:0', '...
# 3  {'Friday': '7:0-21:0', 'Monday': '7:0-20:0', '...
# 4  {'Friday': '12:0-22:0', 'Saturday': '12:0-22:0...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225572 entries, 0 to 225571
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   address       225572 non-null  object
#  1   attributes    204971 non-null  object
#  2   categories    225415 non-null  object
#  3   city          225572 non-null  object
#  4   is_open       225572 non-null  int64
#  5   latitude      225572 non-null  float64
#  6   longitude     225572 non-null  float64
#  7   name          225572 non-null  object
#  8   postal_code   225572 non-null  object
#  9   review_count  225572 non-null  int64
#  10  stars         225572 non-null  float64
#  11  state         225572 non-null  object
#  12  business_id   158001 non-null  object
#  13  hours         190686 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 24.1+ MB

# %%
df.isna().sum()
# Out:
# address             0
# attributes      20601
# categories        157
# city                0
# is_open             0
# latitude            0
# longitude           0
# name                0
# postal_code         0
# review_count        0
# stars               0
# state               0
# business_id     67571
# hours           34886
# dtype: int64

# %%
import json

# Convert columns containing dictionaries into JSON strings for better storage and processing.
columns_to_convert = ["attributes", "hours"]

for col in columns_to_convert:
    df[col] = df[col].apply(lambda x: json.dumps(x) if isinstance(x, dict) else x)

# %%
df.drop_duplicates(inplace=True)
print(f"✅ After removing duplicates, {len(df)} rows remain")
# Out:
# ✅ After removing duplicates, 178399 rows remain

# %%
df_sorted = df.sort_values(by="name")
df_sorted
# Out:
#                                address  \
# 69775                 830 Kirkwood Ave
# 33991                   6802 Ridge Ave
# 144788                 112 S Center St
# 57020                 8131 Kingston St
# 33505           14351 N Dale Mabry Hwy
# ...                                ...
# 31365                   900 Terry Pkwy
# 85930                    109 S 10th St
# 17887   943 E University Blvd, Ste 101
# 129908                   750 Ladera Ln
# 47720                  1010 Anacapa St
#
#                                                attributes  \
# 69775              {"BusinessAcceptsCreditCards": "True"}
# 33991   {"BikeParking": "True", "BusinessAcceptsCredit...
# 144788  {"BusinessAcceptsCreditCards": "True", "Busine...
# 57020   {"BikeParking": "True", "BusinessAcceptsBitcoi...
# 33505   {"Ambience": "{'touristy': False, 'hipster': F...
# ...                                                   ...
# 31365   {"BikeParking": "True", "BusinessAcceptsBitcoi...
# 85930   {"Alcohol": "u'beer_and_wine'", "Ambience": "{...
# 17887                                                 NaN
# 129908  {"BikeParking": "True", "BusinessAcceptsCredit...
# 47720   {"AcceptsInsurance": "False", "BusinessAccepts...
#
#                                                categories           city  \
# 69775   Preschools, Education, Local Services, Child C...      Nashville
# 33991                              Beauty & Spas, Barbers   Philadelphia
# 144788                             Barbers, Beauty & Spas     Plainfield
# 57020   Arts & Entertainment, Venues & Event Spaces, E...           Avon
# 33505   Pizza, Breakfast & Brunch, Restaurants, Food, ...          Tampa
# ...                                                   ...            ...
# 31365      Bakeries, Food, Desserts, Patisserie/Cake Shop      Terrytown
# 85930              Restaurants, Cafes, Food, Coffee & Tea          Boise
# 17887   Apartments, University Housing, Home Services,...         Tucson
# 129908  Real Estate, Home Services, Churches, Fitness ...      Montecito
# 47720   Beauty & Spas, Massage Therapy, Massage, Natur...  Santa Barbara
#
#         is_open   latitude   longitude  \
# 69775         1  36.121090  -86.779848
# 33991         1  40.042395  -75.226518
# 144788        1  39.702890  -86.402923
# 57020         0  39.759701  -86.378301
# 33505         0  28.077936  -82.506174
# ...         ...        ...         ...
# 31365         1  29.892304  -90.031530
# 85930         1  43.616756 -116.206361
# 17887         1  32.232275 -110.957672
# 129908        1  34.440557 -119.578843
# 47720         0  34.422961 -119.700986
#
#                                                      name postal_code  \
# 69775                                        Grow Academy       37204
# 33991                         Joe's Throwback Barber Shop       19128
# 144788                                Leland's Barbershop       46168
# 57020                               Xtreme Laser Tag Avon       46123
# 33505                             "Genuino" Italian Cafe'       33618
# ...                                                   ...         ...
# 31365                                    éclair délicieux       70056
# 85930                                              ā café       83702
# 17887                                         ōLiv Tucson       85719
# 129908           ​Silent Stay Meditation & Retreat Center       93108
# 47720   ​​Transformational Abdominal Massage by Jada D...       93101
#
#         review_count  stars state             business_id  \
# 69775              6    3.5    TN                     NaN
# 33991             17    5.0    PA  t7vVRlyF9_lxuL1auqVchg
# 144788             6    4.5    IN                     NaN
# 57020             12    4.0    IN  f9pqgFRKMoN75uqzxd7KHw
# 33505             60    4.5    FL  ihYl-uK0PYNPeFskcNAr-g
# ...              ...    ...   ...                     ...
# 31365             40    4.5    LA  2KlvBObysXe00p7phB45_A
# 85930             48    5.0    ID  VUKhLVz4X4zVS5wwjAxQjg
# 17887             11    1.0    AZ                     NaN
# 129908            33    5.0    CA  QB6O8M_lW3DSvXHhbylEjQ
# 47720             11    5.0    CA                     NaN
#
#                                                     hours
# 69775   {"Friday": "7:0-18:0", "Monday": "7:0-18:0", "...
# 33991   {"Friday": "7:0-19:0", "Monday": "0:0-0:0", "S...
# 144788  {"Friday": "7:0-17:0", "Saturday": "7:0-14:0",...
# 57020   {"Friday": "17:0-23:0", "Saturday": "10:0-23:0...
# 33505   {"Friday": "9:0-23:0", "Saturday": "9:0-23:0",...
# ...                                                   ...
# 31365   {"Friday": "10:0-19:0", "Monday": "0:0-0:0", "...
# 85930   {"Friday": "8:0-15:0", "Monday": "0:0-0:0", "S...
# 17887   {"Friday": "10:0-19:0", "Monday": "0:0-0:0", "...
# 129908  {"Friday": "9:0-17:0", "Monday": "9:0-17:0", "...
# 47720                                                 NaN
#
# [178399 rows x 14 columns]

# %%
df_sorted.isna().sum()
# Out:
# address             0
# attributes      16262
# categories        123
# city                0
# is_open             0
# latitude            0
# longitude           0
# name                0
# postal_code         0
# review_count        0
# stars               0
# state               0
# business_id     59621
# hours           27498
# dtype: int64

# %%
duplicates_missing_id = df_sorted[df_sorted.duplicated(subset=df_sorted.columns.difference(["business_id"]), keep=False)]
print(f"Found {len(duplicates_missing_id)} rows where everything is identical except for business_id.")
# Out:
# Found 56106 rows where everything is identical except for business_id.

# %%
# Grouping to keep only unique combinations while retaining business_id
df_filled_ids = df_sorted.dropna(subset=["business_id"]).drop_duplicates(subset=df_sorted.columns.difference(["business_id"]).tolist())

# %%
df_sorted = df_sorted.merge(df_filled_ids[["business_id"] + df_sorted.columns.difference(["business_id"]).tolist()],
                            on=df_sorted.columns.difference(["business_id"]).tolist(),
                            how="left",
                            suffixes=("", "_filled"))

# If business_id is missing, fill it with the matched one
df_sorted["business_id"] = df_sorted["business_id"].fillna(df_sorted["business_id_filled"])

# Remove the temporary column
df_sorted.drop(columns=["business_id_filled"], inplace=True)

# %%
df_sorted.isna().sum()
# Out:
# address             0
# attributes      16262
# categories        123
# city                0
# is_open             0
# latitude            0
# longitude           0
# name                0
# postal_code         0
# review_count        0
# stars               0
# state               0
# business_id     31568
# hours           27498
# dtype: int64

# %%
df_sorted.drop_duplicates(inplace=True)
df_sorted.isna().sum()
# Out:
# address             0
# attributes      13744
# categories        103
# city                0
# is_open             0
# latitude            0
# longitude           0
# name                0
# postal_code         0
# review_count        0
# stars               0
# state               0
# business_id     31568
# hours           23223
# dtype: int64

# %%
# Remove rows with missing business_id and duplicates based on key fields
df_filled_ids = df_sorted.dropna(subset=["business_id"]).drop_duplicates(subset=["name", "city", "address"])

# Merge with the cleaned dataset to fill missing business_id values
df_sorted = df_sorted.merge(df_filled_ids[["name", "city", "address", "business_id"]],
                            on=["name", "city", "address"],
                            how="left",
                            suffixes=("", "_filled"))

# Fill missing business_id values from matched records
df_sorted["business_id"] = df_sorted["business_id"].fillna(df_sorted["business_id_filled"])
df_sorted.drop(columns=["business_id_filled"], inplace=True)

# Check if any NaN values remain in business_id
print(f" Remaining {df_sorted['business_id'].isna().sum()} records with NaN in business_id after update.")
# Out:
#  Remaining 31534 records with NaN in business_id after update.

# %%
df_sorted["business_id"] = df_sorted["business_id"].fillna("Unknown_" + df_sorted.index.to_series().astype(str))

# %% [markdown]
# ## Ensuring Uniqueness and Completeness of `business_id`
#
# ### 🔹 Goal:
# The goal of this transformation is to ensure that `business_id` is **unique and complete**, even if some records are missing their original `business_id`. The approach follows three key steps:
#
#
# ### 1️⃣ Identify and Clean Valid `business_id` Records
# - **Remove rows where `business_id` is missing (`NaN`)** to ensure only valid identifiers are used.
# - **Eliminate duplicate records** based on key fields: `"name"`, `"city"`, `"address"`.
# - This step ensures that we retain a set of **unique, valid business identifiers**.
#
#
# ### 2️⃣ Merge Back Missing `business_id` Values Using Matching Fields
# - Some businesses may exist in the dataset but have **missing `business_id`**.
# - We attempt to **fill missing `business_id` values** by matching on `("name", "city", "address")`.
# - If a record **without `business_id`** has an **exact match** in the cleaned dataset, we inherit that `business_id`.
#
#
# ### 3️⃣ Handle Remaining Missing `business_id` Values
# - If a record **still** has a missing `business_id` after the merge, we generate a **temporary identifier**:
#
#   "Unknown_" + index number

# %%
df_sorted.isna().sum()
# Out:
# address             0
# attributes      13744
# categories        103
# city                0
# is_open             0
# latitude            0
# longitude           0
# name                0
# postal_code         0
# review_count        0
# stars               0
# state               0
# business_id         0
# hours           23223
# dtype: int64

# %%
df_sorted
# Out:
#                                address  \
# 0                     830 Kirkwood Ave
# 1                       6802 Ridge Ave
# 2                      112 S Center St
# 3                     8131 Kingston St
# 4               14351 N Dale Mabry Hwy
# ...                                ...
# 150341                  900 Terry Pkwy
# 150342                   109 S 10th St
# 150343  943 E University Blvd, Ste 101
# 150344                   750 Ladera Ln
# 150345                 1010 Anacapa St
#
#                                                attributes  \
# 0                  {"BusinessAcceptsCreditCards": "True"}
# 1       {"BikeParking": "True", "BusinessAcceptsCredit...
# 2       {"BusinessAcceptsCreditCards": "True", "Busine...
# 3       {"BikeParking": "True", "BusinessAcceptsBitcoi...
# 4       {"Ambience": "{'touristy': False, 'hipster': F...
# ...                                                   ...
# 150341  {"BikeParking": "True", "BusinessAcceptsBitcoi...
# 150342  {"Alcohol": "u'beer_and_wine'", "Ambience": "{...
# 150343                                                NaN
# 150344  {"BikeParking": "True", "BusinessAcceptsCredit...
# 150345  {"AcceptsInsurance": "False", "BusinessAccepts...
#
#                                                categories           city  \
# 0       Preschools, Education, Local Services, Child C...      Nashville
# 1                                  Beauty & Spas, Barbers   Philadelphia
# 2                                  Barbers, Beauty & Spas     Plainfield
# 3       Arts & Entertainment, Venues & Event Spaces, E...           Avon
# 4       Pizza, Breakfast & Brunch, Restaurants, Food, ...          Tampa
# ...                                                   ...            ...
# 150341     Bakeries, Food, Desserts, Patisserie/Cake Shop      Terrytown
# 150342             Restaurants, Cafes, Food, Coffee & Tea          Boise
# 150343  Apartments, University Housing, Home Services,...         Tucson
# 150344  Real Estate, Home Services, Churches, Fitness ...      Montecito
# 150345  Beauty & Spas, Massage Therapy, Massage, Natur...  Santa Barbara
#
#         is_open   latitude   longitude  \
# 0             1  36.121090  -86.779848
# 1             1  40.042395  -75.226518
# 2             1  39.702890  -86.402923
# 3             0  39.759701  -86.378301
# 4             0  28.077936  -82.506174
# ...         ...        ...         ...
# 150341        1  29.892304  -90.031530
# 150342        1  43.616756 -116.206361
# 150343        1  32.232275 -110.957672
# 150344        1  34.440557 -119.578843
# 150345        0  34.422961 -119.700986
#
#                                                      name postal_code  \
# 0                                            Grow Academy       37204
# 1                             Joe's Throwback Barber Shop       19128
# 2                                     Leland's Barbershop       46168
# 3                                   Xtreme Laser Tag Avon       46123
# 4                                 "Genuino" Italian Cafe'       33618
# ...                                                   ...         ...
# 150341                                   éclair délicieux       70056
# 150342                                             ā café       83702
# 150343                                        ōLiv Tucson       85719
# 150344           ​Silent Stay Meditation & Retreat Center       93108
# 150345  ​​Transformational Abdominal Massage by Jada D...       93101
#
#         review_count  stars state             business_id  \
# 0                  6    3.5    TN               Unknown_0
# 1                 17    5.0    PA  t7vVRlyF9_lxuL1auqVchg
# 2                  6    4.5    IN               Unknown_2
# 3                 12    4.0    IN  f9pqgFRKMoN75uqzxd7KHw
# 4                 60    4.5    FL  ihYl-uK0PYNPeFskcNAr-g
# ...              ...    ...   ...                     ...
# 150341            40    4.5    LA  2KlvBObysXe00p7phB45_A
# 150342            48    5.0    ID  VUKhLVz4X4zVS5wwjAxQjg
# 150343            11    1.0    AZ          Unknown_150343
# 150344            33    5.0    CA  QB6O8M_lW3DSvXHhbylEjQ
# 150345            11    5.0    CA          Unknown_150345
#
#                                                     hours
# 0       {"Friday": "7:0-18:0", "Monday": "7:0-18:0", "...
# 1       {"Friday": "7:0-19:0", "Monday": "0:0-0:0", "S...
# 2       {"Friday": "7:0-17:0", "Saturday": "7:0-14:0",...
# 3       {"Friday": "17:0-23:0", "Saturday": "10:0-23:0...
# 4       {"Friday": "9:0-23:0", "Saturday": "9:0-23:0",...
# ...                                                   ...
# 150341  {"Friday": "10:0-19:0", "Monday": "0:0-0:0", "...
# 150342  {"Friday": "8:0-15:0", "Monday": "0:0-0:0", "S...
# 150343  {"Friday": "10:0-19:0", "Monday": "0:0-0:0", "...
# 150344  {"Friday": "9:0-17:0", "Monday": "9:0-17:0", "...
# 150345                                                NaN
#
# [150346 rows x 14 columns]

# %%
import re
from thefuzz import process


# Clean city names
def clean_city_name(city):
    """
    Cleans city names by:
    - Removing leading/trailing spaces
    - Replacing multiple spaces with a single space
    - Converting to Title Case
    - Removing dots and commas
    """
    if pd.isna(city):
        return None
    city = city.strip()
    city = re.sub(r"\s+", " ", city)
    city = city.title()
    city = re.sub(r"[.,]", "", city)
    return city

df_sorted["city"] = df_sorted["city"].apply(clean_city_name)

# Standardize city names using fuzzy matching
unique_cities = df_sorted["city"].dropna().unique()
city_mapping = {}

for city in unique_cities:
    result = process.extractOne(city, city_mapping.keys(), score_cutoff=80)

    if result:
        best_match, score = result
        city_mapping[city] = best_match  # Assign the most appropriate name
    else:
        city_mapping[city] = city   #Keep original name if no match found

df_sorted["city"] = df_sorted["city"].map(city_mapping)

print(f"Total unique cities after processing: {df_sorted['city'].nunique()}")
# Out:
# Total unique cities after processing: 755

# %% [markdown]
# ### 1️⃣ **Cleaning City Names**
# - Remove **leading and trailing spaces**.
# - Replace **multiple spaces** with a **single space**.
# - Convert names to **Title Case**.
# - Remove **dots and commas** for consistency.
#
# ### 2️⃣ **Standardizing City Names with Fuzzy Matching**
# To handle **spelling variations and similar city names**, we use **fuzzy matching**:
# - Extract a list of **unique city names**.
# - Compare each city against the existing standardized names.
# - If a match **above 80% similarity** is found, use the best match.
# - Otherwise, retain the original city name.

# %%
for city in sorted(df_sorted["city"].unique()):
    print(city)
# Out:
# Abington
# Afton
# Alberta Park Industrial
# Aldan
# Algiers
# Aliso Viejo
# Alloway
# Almonesson
# Alton
# Ambler
# Andalusia
# Antioch
# Apollo Beach
# Apopka
# Arabi
# Ardmore
# Arizona
# Arnold
# Ashland
# Ashland City
# Aston
# Atco
# Audubon
# Austin
# Avon
# Bala Cynwyd
# Ballwin
# Balm
# Bargersville
# Barnhart
# Barto
# Bayonet Point
# Bear
# Beaumont
# Beech Grove
# Bel Ridge
# Belle Chasse
# Belle Meade
# Belleair
# Belleair Bluffs
# Bellefontaine
# Bellefonte
# Belleville
# Bellevue
# Bellmawr
# Bellville
# Belmont Hills
# Bennington
# Bensalem
# Berkeley
# Berlin
# Berwyn
# Bethel Township
# Beverly
# Birchrunville
# Black Jack
# Blackwood
# Blooming Glen
# Blue Bell
# Blvd
# Boise
# Boone
# Boothwyn
# Bordentown
# Boston
# Boulevard
# Boutte
# Boyertown
# Bradenton
# Brandon
# Breckenridge Hills
# Brentwood
# Brentwood - Cool Springs
# Bridge City
# Bridgeport
# Bridgeton
# Bristol
# Brookhaven
# Brooklawn
# Brooksville
# Broomall
# Brownsburg
# Bryn Athyn
# Bryn Mawr
# Buckingham
# Bucks
# Burlington
# Bywater
# Cahokia
# Caln
# Camby
# Camden
# Cane Ridge
# Carmel
# Carneys Point
# Carpinteria
# Carrollwood
# Casas Adobes
# Caseyville
# Catalina
# Cedar Brook
# Cedars
# Center City Philadelphia
# Centreville
# Cerritos
# Chadds Ford
# Chalfont
# Chalmette
# Charlack
# Charlotte
# Chattanooga
# Cheltenham
# Cherry Hill
# Chesilhurst
# Chester
# Chesterfield
# Chicago
# Christiana
# Churchville
# Cinnaminson
# Citrus Park
# Clarksboro
# Clarksville
# Claymont
# Clayton
# Clearwater
# Clermont
# Clifton Heights
# Coatesville
# College Place
# Collegeville
# Collingdale
# Collingswood
# Collinsville
# Colmar
# Columbia
# Columbus
# Concordville
# Conshohocken
# Cornwells Heights
# Cortaro
# Costa Mesa
# Cottage Hills
# Covington
# Creamery
# Crestwood
# Creve Coeur
# Crosswicks
# Croydon
# Crum Lynne
# Danboro
# Danville
# Delanco
# Delaware County
# Delran
# Denver
# Deptford
# Des Peres
# Devon
# Donelson
# Douglassville
# Dover
# Downingtown
# Doylestown
# Dresher
# Drexel
# Drexel Hill
# Dublin
# Dumont
# Dunedin
# Dunnellon
# Dupo
# Eagle
# Eagleville
# East Falls
# East Nashville
# East Norriton
# East Saint Louis
# Eastampton
# Eastampton Township
# Eaux Claires
# Echelon
# Eddystone
# Edgemont
# Edgemoor
# Edgewater Park
# Edmonton
# Edmundson
# Edwardsville
# Elfers
# Elk Township
# Elkins Park
# Elmer
# Elmwood
# Elverson
# Enoch
# Erdenheim
# Essington
# Evesham Township
# Evshm Twp
# Ewing
# Exton
# Fairland
# Fairless Hills
# Fairview Heights
# Falls
# Feasterville
# Feasterville Trevose
# Fenton
# Ferguson
# Fernley
# Fieldsboro
# Fishers
# Flanders
# Florence
# Florissant
# Flourtown
# Folcroft
# Folsom
# Forest Grove
# Fort Saskatchewan
# Fort Washington
# Fortville
# Foster Pond
# Fountainville
# Fox Street
# Franconia
# Franklin
# Frazer
# Frederick
# Freeburg
# Freehold
# French Quarter - Cbd
# Frontenac
# Furlong
# Gallatin
# Garden City
# Garnet Valley
# Gentilly
# Gibbsboro
# Gibbstown
# Gibsonton
# Glassboro
# Glen Carbon
# Glen Mills
# Glendale
# Glendora
# Glenmoore
# Glenolden
# Glenside
# Gloucester Township
# Godfrey
# Goleta
# Goodlettsville
# Gradyville
# Granite City
# Greater Northdale
# Green Lane
# Green Park
# Green Valley
# Greenbrier
# Greenfield
# Greenville
# Greenwood
# Grenloch
# Gretna
# Gulfport
# Gulph Mills
# Gwynedd Valley
# Had Twp
# Hadden
# Haddon Heights
# Haddon Township
# Haddonfield
# Hainesport
# Hamilton
# Hammonton
# Hancock
# Harahan
# Harleysville
# Hartsville
# Harvey
# Hatboro
# Hatfield
# Haverford
# Havertown
# Hazelwood
# Hendersonville
# Hermitage
# Hernando Beach
# Hi-Nella
# High Ridge
# Hillsborough County
# Hilltown
# Hockessin
# Holicong
# Holiday
# Holland
# Hollywood
# Holmes
# Honey Brook
# Hopewell Township
# Horseshoe Bend
# Horsham
# Houston
# Hudson
# Hulmeville
# Huntingdon Valley
# Hurffville
# Imperial
# Indian Rocks Beach
# Indian Shores
# Indianapolis
# Indianpolis
# Inglewood
# Isla Vista
# Ivyland
# Jamison
# Jefferson
# Jenkintown
# Jennings
# Jobstown
# Joelton
# Johnson
# Kalispell
# Kenner
# Kenneth City
# Kennett Square
# Kimberton
# Kimmswick
# King Of Prussia
# Kingston Springs
# Kirklyn
# Kirkwood
# Knoxville
# Kop
# Kulpsville
# Kuna
# La Vergne
# Ladue
# Lafayette Hill
# Lahaska
# Lakeland
# Lambertville
# Land O Lakes
# Land O' Lakes
# Langhorne
# Lansdale
# Lansdowne
# Largo
# Laurel Springs
# Lawnside
# Lawrence
# Lawrenceville
# Lebanon
# Lederach
# Lemay Ferry
# Lenni
# Lester
# Levittown
# Lima
# Limerick
# Lincoln
# Lindenwold
# Line Lexington
# Linfield
# Linwood
# Lionville
# Lithia
# Liverpool
# London Grove
# Los Angeles
# Los Ranchitos
# Lower Gwynedd Township
# Lower Merion
# Lower Southampton Township
# Lula Lula
# Luling
# Lumberton
# Lutz
# Macdill Afb
# Madeira Beach
# Madison
# Magnolia
# Malaga
# Malvern
# Manayunk
# Mandeville
# Mango
# Mansfield
# Mantua Township
# Maple Shade
# Maple Shade Township
# Maplewood
# Marana
# Marcus Hook
# Marlborough
# Marlton
# Marrero
# Maryland Heights
# Masaryktown
# Mascoutah
# Mccarran
# Mccordsville
# Meadowbrook
# Medford
# Media
# Mehlville
# Melrose Park
# Mendenhall
# Meraux
# Mercerville
# Merchantville
# Meridian
# Merion Park
# Merion Station
# Metairie
# Metarie
# Middletown
# Millstadt
# Mission Canyon
# Mississauga
# Monroe Township
# Monrovia
# Montchanin
# Montecito
# Montgomeryville
# Moorestown
# Mooresville
# Morton
# Mount Ephraim
# Mount Holly
# Mount Laurel
# Mount Laurel Township
# Mt Airy
# Mt Juliet
# Mt Laurel
# Mulberry
# Mullica Hill
# Murfreesboro
# N Redngtn Bch
# Narberth
# Nashville
# National Park
# New Britain
# New Castle
# New Hope
# New Orleans
# New Port Richey
# Newark
# Newfield
# Newport
# Newtown
# Newtown Square
# Nixa
# Nolensville
# Normandy
# Norristown
# Norritown
# North Coventry
# North Redington Bch
# North Redington Beach
# North Wales
# Norwood
# O'Fallon
# Oakford
# Oaklandon
# Oaklyn
# Oaks
# Oakville
# Odessa
# Old Hickory
# Old Strathcona
# Oldmans
# Oldsmar
# Olivette
# Oracle
# Oreland
# Oro Valley
# Oxnard
# Ozona
# Pagedale
# Palm Harbor
# Palmetto
# Palmyra
# Paoli
# Parker Ford
# Parkside
# Pasadena
# Pasco
# Pass-A-Grille
# Paulsboro
# Pedricktown
# Pegram
# Pemberton
# Penllyn
# Penndel
# Penns Grove
# Pennsauken
# Pennsburg
# Pennsville
# Pennsylvania
# Perkasie
# Perkiomenville
# Philadelphia
# Philly
# Phoenixville
# Picture Rocks
# Pike Creek
# Pilesgrove
# Pilgrim Gardens
# Pine Forge
# Pinellas Park
# Pipersville
# Pitman
# Plainfield
# Plant City
# Pleasant Township
# Pleasant View
# Plumsteadville
# Plymouth Meeting
# Pontoon Beach
# Port Hueneme
# Pottsgrove
# Pottstown
# Primos
# Prospect Park
# Quakertown
# Quinton
# Radnor
# Rancocas
# Red Hill
# Redington Shores
# Reno
# Reno Nevada
# Richboro
# Richmond Heights
# Richwood
# Ridley
# Ridley Park
# Rillito
# River Ridge
# Riverside
# Riverton
# Riverview
# Rock Hill
# Rockledge
# Roebling
# Rosemont
# Rosewood Heights
# Roslyn
# Roxborough
# Royersford
# Runnemede
# Ruskin
# Rutledge
# S Pasadena
# Safety Harbor
# Sahuarita
# Saint Albert
# Saint Davids
# Saint Louis
# Saint Pete Beach
# Saint Petersburg
# Saint Petersburg Beach
# Salinas
# San Anselmo
# San Antonio
# Sanatoga
# Santa Barbara
# Santa Barbara & Ventura Counties
# Santa Rita
# Santa Ynez
# Sappington
# Sarasota
# Sassamansville
# Sauget
# Schwenksville
# Scott Afb
# Secane
# Seffner
# Seminole
# Sewell
# Shamong
# Sharon Hill
# Sherwood Park
# Shiloh
# Shrewsbury
# Sicklerville
# Silverdale
# Skippack
# Slidell
# Smithton
# Smyrna
# Solebury
# Somerdale
# Souderton
# South Cherry Hill
# South County
# South Harrison Township
# South Pasadena
# South Reno
# South Roxana
# Southampton
# Southampton Township
# Southeastern
# Southport
# Spanish Springs
# Sparks
# Speedway
# Spokane
# Spring City
# Spring Hill
# Spring House
# Springfield
# Spruce Grove
# St Ann
# St Charles
# St Louis
# St Louis County
# St Pete Beach
# St Petersburg
# St Rose
# StAnn
# Star
# Stowe
# Stratford
# Stroudsburg
# Sturgeon Couny
# Sullivan
# Summerhaven
# Summerland
# Sumneytown
# Sun City Center
# Sunset Hills
# Swansea
# Swarthmore
# Swedeland
# Swedesboro
# Tabernacle
# Talleyville
# Tampa
# Tampa - South
# Tarpon Springs
# Telford
# Temple Terrace
# Tennesse
# Terra Ceia
# Terrytown
# Thonotosassa
# Thorndale
# Thorofare
# Tierra Verde
# Tinicum Township
# Titusville
# Tortola
# Toughkenamon
# Town & Country
# Town 'N' Country
# Town And Country
# Town N Country
# Trainer
# Trappe
# Treasure Island
# Trenton
# Trinity
# Trolley Square
# Trooper
# Troy
# Truckee
# Tucson
# Tullytown
# Turnersville
# Tylersport
# University City
# Upland
# Upper Chichester
# Upper Darby
# Upper Pittsgrove
# Uppr Blck Edy
# Vail
# Valencia West
# Valley Forge
# Valrico
# Vc Highlands
# Ventura
# Verdi
# View
# Villanova
# Vincentown
# Vineland
# Violet
# Virtual
# Voorhees
# Waggaman
# Wales
# Wallingford
# Wanamaker
# Warminster
# Warrington
# Warson Woods
# Warwick
# Washington
# Washington Crossing
# Washington Township
# Washoe Valley
# Waterford Works
# Waterloo
# Wayne
# Webster Groves
# Wenonah
# Wesley Chapel
# West Bradford Township
# West Chester
# West Conshohocken
# West Edmonton
# West Hill
# Westampton
# Westchase
# Westfield
# Westmont
# Westtown
# Westville
# Westwego
# White House
# Whiteland
# Whites Creek
# Whitestown
# Williamsport
# Williamstown
# Willingboro
# Willow Grove
# Wilmington
# Wimauma
# Winslow
# Winterthur
# Wood River
# Woodbourne
# Woodbury
# Woodlyn
# Woodson Terrace
# Woodstown
# Woolwich Township
# Wrightstown
# Wycombe
# Wyncote
# Wyndlake Condominium
# Wyndmoor
# Wynnewood
# Yardley
# Yeadon
# Yorklyn
# Zephyrhills
# Zieglerville
# Zionsville

# %%
df_sorted
# Out:
#                                address  \
# 0                     830 Kirkwood Ave
# 1                       6802 Ridge Ave
# 2                      112 S Center St
# 3                     8131 Kingston St
# 4               14351 N Dale Mabry Hwy
# ...                                ...
# 150341                  900 Terry Pkwy
# 150342                   109 S 10th St
# 150343  943 E University Blvd, Ste 101
# 150344                   750 Ladera Ln
# 150345                 1010 Anacapa St
#
#                                                attributes  \
# 0                  {"BusinessAcceptsCreditCards": "True"}
# 1       {"BikeParking": "True", "BusinessAcceptsCredit...
# 2       {"BusinessAcceptsCreditCards": "True", "Busine...
# 3       {"BikeParking": "True", "BusinessAcceptsBitcoi...
# 4       {"Ambience": "{'touristy': False, 'hipster': F...
# ...                                                   ...
# 150341  {"BikeParking": "True", "BusinessAcceptsBitcoi...
# 150342  {"Alcohol": "u'beer_and_wine'", "Ambience": "{...
# 150343                                                NaN
# 150344  {"BikeParking": "True", "BusinessAcceptsCredit...
# 150345  {"AcceptsInsurance": "False", "BusinessAccepts...
#
#                                                categories           city  \
# 0       Preschools, Education, Local Services, Child C...      Nashville
# 1                                  Beauty & Spas, Barbers   Philadelphia
# 2                                  Barbers, Beauty & Spas     Plainfield
# 3       Arts & Entertainment, Venues & Event Spaces, E...           Avon
# 4       Pizza, Breakfast & Brunch, Restaurants, Food, ...          Tampa
# ...                                                   ...            ...
# 150341     Bakeries, Food, Desserts, Patisserie/Cake Shop      Terrytown
# 150342             Restaurants, Cafes, Food, Coffee & Tea          Boise
# 150343  Apartments, University Housing, Home Services,...         Tucson
# 150344  Real Estate, Home Services, Churches, Fitness ...      Montecito
# 150345  Beauty & Spas, Massage Therapy, Massage, Natur...  Santa Barbara
#
#         is_open   latitude   longitude  \
# 0             1  36.121090  -86.779848
# 1             1  40.042395  -75.226518
# 2             1  39.702890  -86.402923
# 3             0  39.759701  -86.378301
# 4             0  28.077936  -82.506174
# ...         ...        ...         ...
# 150341        1  29.892304  -90.031530
# 150342        1  43.616756 -116.206361
# 150343        1  32.232275 -110.957672
# 150344        1  34.440557 -119.578843
# 150345        0  34.422961 -119.700986
#
#                                                      name postal_code  \
# 0                                            Grow Academy       37204
# 1                             Joe's Throwback Barber Shop       19128
# 2                                     Leland's Barbershop       46168
# 3                                   Xtreme Laser Tag Avon       46123
# 4                                 "Genuino" Italian Cafe'       33618
# ...                                                   ...         ...
# 150341                                   éclair délicieux       70056
# 150342                                             ā café       83702
# 150343                                        ōLiv Tucson       85719
# 150344           ​Silent Stay Meditation & Retreat Center       93108
# 150345  ​​Transformational Abdominal Massage by Jada D...       93101
#
#         review_count  stars state             business_id  \
# 0                  6    3.5    TN               Unknown_0
# 1                 17    5.0    PA  t7vVRlyF9_lxuL1auqVchg
# 2                  6    4.5    IN               Unknown_2
# 3                 12    4.0    IN  f9pqgFRKMoN75uqzxd7KHw
# 4                 60    4.5    FL  ihYl-uK0PYNPeFskcNAr-g
# ...              ...    ...   ...                     ...
# 150341            40    4.5    LA  2KlvBObysXe00p7phB45_A
# 150342            48    5.0    ID  VUKhLVz4X4zVS5wwjAxQjg
# 150343            11    1.0    AZ          Unknown_150343
# 150344            33    5.0    CA  QB6O8M_lW3DSvXHhbylEjQ
# 150345            11    5.0    CA          Unknown_150345
#
#                                                     hours
# 0       {"Friday": "7:0-18:0", "Monday": "7:0-18:0", "...
# 1       {"Friday": "7:0-19:0", "Monday": "0:0-0:0", "S...
# 2       {"Friday": "7:0-17:0", "Saturday": "7:0-14:0",...
# 3       {"Friday": "17:0-23:0", "Saturday": "10:0-23:0...
# 4       {"Friday": "9:0-23:0", "Saturday": "9:0-23:0",...
# ...                                                   ...
# 150341  {"Friday": "10:0-19:0", "Monday": "0:0-0:0", "...
# 150342  {"Friday": "8:0-15:0", "Monday": "0:0-0:0", "S...
# 150343  {"Friday": "10:0-19:0", "Monday": "0:0-0:0", "...
# 150344  {"Friday": "9:0-17:0", "Monday": "9:0-17:0", "...
# 150345                                                NaN
#
# [150346 rows x 14 columns]

# %%
# Split categories by comma and expand them into separate rows
df_exploded = df_sorted.assign(categories=df_sorted["categories"].str.split(",")).explode("categories")

# Remove extra spaces and convert to Title Case
df_exploded["categories"] = df_exploded["categories"].str.strip().str.title()


print(f"Total unique categories after processing: {df_exploded['categories'].nunique()}")

df_sorted = df_exploded
# Out:
# Total unique categories after processing: 1311

# %% [markdown]
# ### 1️⃣ **Splitting Categories into Separate Rows**
# - The original dataset may have multiple categories **stored in a single row**, separated by commas.
# - We use `.str.split(",")` to break **multi-category values** into **lists**.
# - The `.explode("categories")` function expands these **lists into separate rows**.
#
#
# ### 2️⃣ **Cleaning Category Names**
# After expansion, we further clean category names by:
# - **Removing leading/trailing spaces** to avoid inconsistencies.
# - **Converting names to Title Case**.

# %%
df_sorted
# Out:
#                  address                                         attributes  \
# 0       830 Kirkwood Ave             {"BusinessAcceptsCreditCards": "True"}
# 0       830 Kirkwood Ave             {"BusinessAcceptsCreditCards": "True"}
# 0       830 Kirkwood Ave             {"BusinessAcceptsCreditCards": "True"}
# 0       830 Kirkwood Ave             {"BusinessAcceptsCreditCards": "True"}
# 1         6802 Ridge Ave  {"BikeParking": "True", "BusinessAcceptsCredit...
# ...                  ...                                                ...
# 150345   1010 Anacapa St  {"AcceptsInsurance": "False", "BusinessAccepts...
# 150345   1010 Anacapa St  {"AcceptsInsurance": "False", "BusinessAccepts...
# 150345   1010 Anacapa St  {"AcceptsInsurance": "False", "BusinessAccepts...
# 150345   1010 Anacapa St  {"AcceptsInsurance": "False", "BusinessAccepts...
# 150345   1010 Anacapa St  {"AcceptsInsurance": "False", "BusinessAccepts...
#
#                           categories           city  is_open   latitude  \
# 0                         Preschools      Nashville        1  36.121090
# 0                          Education      Nashville        1  36.121090
# 0                     Local Services      Nashville        1  36.121090
# 0              Child Care & Day Care      Nashville        1  36.121090
# 1                      Beauty & Spas   Philadelphia        1  40.042395
# ...                              ...            ...      ...        ...
# 150345                       Massage  Santa Barbara        0  34.422961
# 150345         Naturopathic/Holistic  Santa Barbara        0  34.422961
# 150345              Health & Medical  Santa Barbara        0  34.422961
# 150345  Traditional Chinese Medicine  Santa Barbara        0  34.422961
# 150345                       Doctors  Santa Barbara        0  34.422961
#
#          longitude                                               name  \
# 0       -86.779848                                       Grow Academy
# 0       -86.779848                                       Grow Academy
# 0       -86.779848                                       Grow Academy
# 0       -86.779848                                       Grow Academy
# 1       -75.226518                        Joe's Throwback Barber Shop
# ...            ...                                                ...
# 150345 -119.700986  ​​Transformational Abdominal Massage by Jada D...
# 150345 -119.700986  ​​Transformational Abdominal Massage by Jada D...
# 150345 -119.700986  ​​Transformational Abdominal Massage by Jada D...
# 150345 -119.700986  ​​Transformational Abdominal Massage by Jada D...
# 150345 -119.700986  ​​Transformational Abdominal Massage by Jada D...
#
#        postal_code  review_count  stars state             business_id  \
# 0            37204             6    3.5    TN               Unknown_0
# 0            37204             6    3.5    TN               Unknown_0
# 0            37204             6    3.5    TN               Unknown_0
# 0            37204             6    3.5    TN               Unknown_0
# 1            19128            17    5.0    PA  t7vVRlyF9_lxuL1auqVchg
# ...            ...           ...    ...   ...                     ...
# 150345       93101            11    5.0    CA          Unknown_150345
# 150345       93101            11    5.0    CA          Unknown_150345
# 150345       93101            11    5.0    CA          Unknown_150345
# 150345       93101            11    5.0    CA          Unknown_150345
# 150345       93101            11    5.0    CA          Unknown_150345
#
#                                                     hours
# 0       {"Friday": "7:0-18:0", "Monday": "7:0-18:0", "...
# 0       {"Friday": "7:0-18:0", "Monday": "7:0-18:0", "...
# 0       {"Friday": "7:0-18:0", "Monday": "7:0-18:0", "...
# 0       {"Friday": "7:0-18:0", "Monday": "7:0-18:0", "...
# 1       {"Friday": "7:0-19:0", "Monday": "0:0-0:0", "S...
# ...                                                   ...
# 150345                                                NaN
# 150345                                                NaN
# 150345                                                NaN
# 150345                                                NaN
# 150345                                                NaN
#
# [668695 rows x 14 columns]

# %% [markdown]
# # ATC 1 Data Preparation and Cleanup
#
# ## Objectives:
# - Deduplicate ATC 1 definitions table while preserving the most accurate and up-to-date information.
# - Ensure all transformations follow best practices.
# - Prepare the dataset for a **JOIN operation** with a large hospital dataset (~500k rows).
# - Optimize processing for **datalake** scenarios.
#
# ## Assumptions:
# - The dataset contains `valid_from` and `valid_to` columns for time-based filtering.
# - Some ATC 1 definitions might have multiple entries due to updates.
# - The hospital dataset is large, so scalability is a concern.
#
# ## Key Steps:
# 1. **Load raw data**.
# 2. **Convert date columns to DateType** for proper time handling.
# 3. **Deduplicate records** while keeping the most recent versions.
# 4. **Perform a JOIN** with the hospital dataset.
# 5. **Optimize for scalability**, ensuring the approach works for big data processing.

# %%
import pandas as pd
from datetime import datetime

# %%
atc = [
    ("1900-01-01", "9999-12-31", "A", "Maagdarmkanaal en Metabolisme", "Alimentary Tract and Metabolism"),
    ("1900-01-01", "9999-12-31", "B", "Bloed en Bloedvormende Organen", "Blood and Blood Forming Organs"),
    ("1900-01-01", "9999-12-31", "C", "Hartvaatstelsel", "Cardiovascular System"),
    ("1900-01-01", "9999-12-31", "D", "Dermatologica", "Dermatologicals"),
    ("1900-01-01", "9999-12-31", "G", "Urogenitale Stelsel en Geslachtshormonen", "Genito Urinary System and Sex Hormones"),
    ("1900-01-01", "2022-01-30", "H", "Systemische Hormoonpreparaten, Excl Geslachtshormonen", "Systemic Hormonal Prep,Excl Sex Hormones"),
    ("2022-01-31", "9999-12-31", "H", "Systemische Hormoonpreparaten, Excl Geslachtshormonen", "Systemic Hormonal Preparations, Excl. Sex Hormones and Insulins"),
    ("1900-01-01", "2022-01-30", "J", "Antimicrobiele Middelen Voor Systemisch Gebruik", "General Antiinfectives for Systemic Use"),
    ("2022-01-31", "9999-12-31", "J", "Antimicrobiele Middelen Voor Systemisch Gebruik", "Antiinfectives for Systemic Use"),
    ("1900-01-01", "9999-12-31", "L", "Oncolytica en Immunomodulantia", "Antineoplastic and Immunomodulating Agents"),
    ("1900-01-01", "9999-12-31", "M", "Skeletspierstelsel", "Musculo-Skeletal System"),
    ("1900-01-01", "9999-12-31", "N", "Zenuwstelsel", "Nervous System"),
    ("1900-01-01", "2022-01-30", "P", "Antiparasitica, Insecticiden en Insectenwerende Middelen", "Antiparasitic Products,Insecticides and Repellents"),
    ("2022-01-31", "9999-12-31", "P", "Antiparasitica, Insecticiden en Insectenwerende Middelen", "Antiparasitic Products, Insecticides and Repellents"),
    ("1900-01-01", "9999-12-31", "R", "Ademhalingsstelsel", "Respiratory System"),
    ("1900-01-01", "9999-12-31", "S", "Zintuiglijke Organen", "Sensory Organs"),
    ("1900-01-01", "9999-12-31", "V", "Diverse Middelen", "Various"),
    ("1900-01-01", "2024-12-30", "Y", "Niet Ingevuld", "Not filled in"),
    ("2024-12-31", "9999-12-31", "Y", "Niet Ingevuld", None),
    ("1900-01-01", "2024-12-30", "Z", "Niet Van Toepassing", "Not applicable"),
    ("2024-12-31", "9999-12-31", "Z", "Niet Van Toepassing", None)
]

df = pd.DataFrame(atc, columns=["valid_from", "valid_to", "code", "description", "description_en"])

# Convert date columns from string to datetime format
df["valid_to"] = df["valid_to"].replace("9999-12-31", "2099-12-31")

# Převod sloupců na datetime a nastavení přesnosti na den
df["valid_from"] = pd.to_datetime(df["valid_from"]).astype("datetime64[ms]")
df["valid_to"] = pd.to_datetime(df["valid_to"]).astype("datetime64[ms]")

# Nastavení NaT ve sloupci "valid_to", pokud hodnota odpovídá '9999-12-31'
df.loc[df["valid_to"] == pd.Timestamp("9999-12-31"), "valid_to"] = pd.NaT
df.head()
# Out:
#   valid_from   valid_to code                               description  \
# 0 1900-01-01 2099-12-31    A             Maagdarmkanaal en Metabolisme
# 1 1900-01-01 2099-12-31    B            Bloed en Bloedvormende Organen
# 2 1900-01-01 2099-12-31    C                           Hartvaatstelsel
# 3 1900-01-01 2099-12-31    D                             Dermatologica
# 4 1900-01-01 2099-12-31    G  Urogenitale Stelsel en Geslachtshormonen
#
#                            description_en
# 0         Alimentary Tract and Metabolism
# 1          Blood and Blood Forming Organs
# 2                   Cardiovascular System
# 3                         Dermatologicals
# 4  Genito Urinary System and Sex Hormones

# %%
# Deduplicate by keeping the most recent valid_from record for each code
df = df.sort_values(by=["code", "valid_from"], ascending=[True, False])
df = df.drop_duplicates(subset=["code"], keep="first")

# Display results
df
# Out:
#    valid_from   valid_to code  \
# 0  1900-01-01 2099-12-31    A
# 1  1900-01-01 2099-12-31    B
# 2  1900-01-01 2099-12-31    C
# 3  1900-01-01 2099-12-31    D
# 4  1900-01-01 2099-12-31    G
# 6  2022-01-31 2099-12-31    H
# 8  2022-01-31 2099-12-31    J
# 9  1900-01-01 2099-12-31    L
# 10 1900-01-01 2099-12-31    M
# 11 1900-01-01 2099-12-31    N
# 13 2022-01-31 2099-12-31    P
# 14 1900-01-01 2099-12-31    R
# 15 1900-01-01 2099-12-31    S
# 16 1900-01-01 2099-12-31    V
# 18 2024-12-31 2099-12-31    Y
# 20 2024-12-31 2099-12-31    Z
#
#                                           description  \
# 0                       Maagdarmkanaal en Metabolisme
# 1                      Bloed en Bloedvormende Organen
# 2                                     Hartvaatstelsel
# 3                                       Dermatologica
# 4            Urogenitale Stelsel en Geslachtshormonen
# 6   Systemische Hormoonpreparaten, Excl Geslachtsh...
# 8     Antimicrobiele Middelen Voor Systemisch Gebruik
# 9                      Oncolytica en Immunomodulantia
# 10                                 Skeletspierstelsel
# 11                                       Zenuwstelsel
# 13  Antiparasitica, Insecticiden en Insectenwerend...
# 14                                 Ademhalingsstelsel
# 15                               Zintuiglijke Organen
# 16                                   Diverse Middelen
# 18                                      Niet Ingevuld
# 20                                Niet Van Toepassing
#
#                                        description_en
# 0                     Alimentary Tract and Metabolism
# 1                      Blood and Blood Forming Organs
# 2                               Cardiovascular System
# 3                                     Dermatologicals
# 4              Genito Urinary System and Sex Hormones
# 6   Systemic Hormonal Preparations, Excl. Sex Horm...
# 8                     Antiinfectives for Systemic Use
# 9          Antineoplastic and Immunomodulating Agents
# 10                            Musculo-Skeletal System
# 11                                     Nervous System
# 13  Antiparasitic Products, Insecticides and Repel...
# 14                                 Respiratory System
# 15                                     Sensory Organs
# 16                                            Various
# 18                                               None
# 20                                               None

# %%
# Simulated hospital dataset ( it would contain ~500k rows)
hospital_data = [
    ("A", "Some medical data 1"),
    ("B", "Some medical data 2"),
    ("C", "Some medical data 3"),
    ("H", "Some medical data 4"),
]

hospital_df = pd.DataFrame(hospital_data, columns=["code", "hospital_info"])

# Perform a left JOIN to retain all ATC 1 data
merged_df = df.merge(hospital_df, on="code", how="left")

# Display first rows
merged_df.head()
# Out:
#   valid_from   valid_to code                               description  \
# 0 1900-01-01 2099-12-31    A             Maagdarmkanaal en Metabolisme
# 1 1900-01-01 2099-12-31    B            Bloed en Bloedvormende Organen
# 2 1900-01-01 2099-12-31    C                           Hartvaatstelsel
# 3 1900-01-01 2099-12-31    D                             Dermatologica
# 4 1900-01-01 2099-12-31    G  Urogenitale Stelsel en Geslachtshormonen
#
#                            description_en        hospital_info
# 0         Alimentary Tract and Metabolism  Some medical data 1
# 1          Blood and Blood Forming Organs  Some medical data 2
# 2                   Cardiovascular System  Some medical data 3
# 3                         Dermatologicals                  NaN
# 4  Genito Urinary System and Sex Hormones                  NaN

# %%
# Save as Parquet for efficient storage
merged_df.to_parquet("processed_atc_data.parquet", engine="pyarrow", index=False)
print("✅ Data successfully saved to Parquet!")

# %% [markdown]
# ## Summary of Data Processing Decisions
#
# ✔ **Converted date columns to `datetime` format** for proper time-based analysis.
#
# ✔ **Removed duplicates** while keeping the latest valid records.
#
# ✔ **Used efficient JOIN** (left merge) to combine with hospital data.
#
# ✔ **Saved in Parquet format** to ensure scalability for large datasets.

# %% [markdown]
# # 📌 Data Lake Use Case: Scalable and Efficient Data Ingestion & Serving
#
# ## 1️⃣ Data Ingestion (Efficient and Scalable Data Loading)
#
# ### 🔹 Choosing the Right Storage Format
#
# | File Format | Advantages | Use Case |
# |------------|------------|------------|
# | **Parquet** | Columnar format, high compression, fast read/write | Best for analytical queries, data lakes |
# | **CSV / JSON** | Human-readable, flexible, but inefficient | Suitable for raw data staging only |
#
# 📌 **Best Choice:** **Parquet** due to its **compression and analytical efficiency**.

# %% [markdown]
# ### 🔹 Batch vs. Streaming Ingestion
# Depending on the data source and business needs, we can use **Batch Processing** or **Streaming Processing**.
#
# | **Ingestion Type** | **Description** | **Tools & Technologies** | **Example Use Case** |
# |------------------|----------------------|-------------------|------------------|
# | **Batch Processing** | Loads large datasets at scheduled intervals | Apache Airflow, AWS Glue, Azure Data Factory, Spark | Daily data ingestion from CRM, ERP, and databases |
# | **Streaming Processing** | Ingests data in real-time as events occur | Apache Kafka, Spark Streaming, Apache Flink, AWS Kinesis | IoT sensors, user clickstreams, fraud detection |
#
# ### 🔹 Implementing Batch Processing
# 📌 **Workflow:**
#
# 1️⃣ Extract data from **databases, APIs, or logs**.
#
# 2️⃣ Apply initial **data validation and cleaning**.
#
# 3️⃣ Convert into **Parquet format** and store in the **Raw Data Zone**.
#
# 4️⃣ Schedule **daily processing** with **Apache Airflow or AWS Glue**.
#
# ### 🔹 Implementing Streaming Processing
# 📌 **Workflow:**
#
# 1️⃣ Data is ingested **in real-time** via **Kafka, AWS Kinesis, or Event Hubs**.
#
# 2️⃣ **Spark Streaming** processes data and applies transformations.
#
# 3️⃣ Data is stored in **Delta Lake** for real-time access.

# %% [markdown]
# ## 2️⃣ Data Serving (Providing Access to Processed Data)
#
# ### 🔹 Key Access Methods
# | Serving Method | Description | Use Case |
# |---------------|------------|------------|
# | **BI Dashboards** | Connects to Tableau, Power BI, Looker | Real-time business intelligence |
# | **REST API Access** | Allows external applications to retrieve data | Web applications, automation |
# | **SQL Querying** | Enables ad-hoc queries via Presto, Athena, DuckDB | Data exploration, analytics |
# | **Automated Reports** | Scheduled reports to business teams | Monthly revenue, user behavior reports |
#
# ### 🔹 Optimizing Query Performance
# To ensure **fast queries**, we apply:
#
# ✔ **Indexing** → Faster lookups (Z-Order, Bloom Filters).
#
# ✔ **Partitioning** → Efficient query pruning (`partition by year, month`).
#
# ✔ **Caching** → Store frequently accessed data in memory (`Spark Cache`).

# %% [markdown]
# # 📌 Enhanced Data Lake Architecture
#
# ## 1️⃣ Data Sources
# ```
# ├── Transactional Systems (OLTP, ODS) – Databases, CRM, ERP
# ├── Enterprise Data Warehouse (EDW) – Centralized Data Storage
# ├── Structured Data – SQL, CSV, JSON
# ├── Unstructured Data – Logs, Files, API Data
# ├── Streaming Data – Kafka, IoT, Clickstream
# ↓
# ```
#
# ## 2️⃣ Data Ingestion (Batch & Streaming)
# ```
# ├── Batch Processing – Apache Airflow, AWS Glue, Azure Data Factory
# ├── Streaming Processing – Kafka, Flink, Spark Streaming
# ├── Initial Validation & Filtering of Incoming Data
# ↓
# ```
#
# ### 📍 Raw Data Zone
# ```
# ├── Stored in Parquet
# ↓
# ```
#
# ## 3️⃣ Data Processing (Cleaning & Enrichment)
# ```
# ├── Data Wrangling (Spark, Pandas)
# ├── Data Quality Management (Apache Deequ)
# ├── Data Transformation (Delta Lake, dbt)
# ├── Tokenization & Encryption – Securing Sensitive Data
# ↓
# ```
#
# ### 📍 Refined Data Zone
# ```
# ├── Stored in Delta Lake / Iceberg
# ↓
# ```
#
# ## 4️⃣ Data Storage (Optimized Storage)
# ```
# ├── Metadata Management – Data Catalog (Glue, Apache Atlas)
# ├── Partitioning & Indexing – Z-Order, Bloom Filters for Performance Optimization
# ↓
# ```
#
# ## 5️⃣ Data Serving (Consumption & Analytics)
# ```
# ├── BI Dashboards – Tableau, Power BI, Looker
# ├── Data API & Access – GraphQL, REST, Athena, Presto
# ├── Machine Learning & AI – Used by Data Scientists for Model Training
# ├── Automated Reports – Business Report Generation
